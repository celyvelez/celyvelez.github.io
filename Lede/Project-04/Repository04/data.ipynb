# %% [markdown]
# ## Imports

# %%
import pandas as pd

# %%
df = pd.read_csv("Datos_de_la_Tasa_compensatoria_por_Caza_de_Fauna_Silvestre.csv")
df.head()
# Out:
#     Año Autoridad Ambiental    NOMBRE/RAZÓN SOCIAL PERSONA NATURAL O JURÍDICA  \
# 0  2021           CORTOLIMA  UNVERSIDAD DEL TOLIMA           Persona jurídica
# 1  2021           CORTOLIMA  UNVERSIDAD DEL TOLIMA           Persona jurídica
# 2  2021           CORTOLIMA  UNVERSIDAD DEL TOLIMA           Persona jurídica
# 3  2021           CORTOLIMA  UNVERSIDAD DEL TOLIMA           Persona jurídica
# 4  2021           CORTOLIMA  UNVERSIDAD DEL TOLIMA           Persona jurídica
#
#     REPRESENTANTE LEGAL       TIPO DE AUTORIZACIÓN / ENTIDAD QUE OTORGA  \
# 0  Omar A. Mejía Patiño  Permiso / Autoridad Ambiental diferente a ANLA
# 1  Omar A. Mejía Patiño  Permiso / Autoridad Ambiental diferente a ANLA
# 2  Omar A. Mejía Patiño  Permiso / Autoridad Ambiental diferente a ANLA
# 3  Omar A. Mejía Patiño  Permiso / Autoridad Ambiental diferente a ANLA
# 4  Omar A. Mejía Patiño  Permiso / Autoridad Ambiental diferente a ANLA
#
# ...

# %% [markdown]
# ## Value Counts

# %%
df["Autoridad Ambiental"].value_counts()
# Out:
# Autoridad Ambiental
# CORTOLIMA       603
# CARDER          492
# CORPOCALDAS     347
# PNN              53
# CRQ              14
# CORPOBOYACA      10
# CORPOGUAJIRA      5
# SDA               2
# Name: count, dtype: int64

# %%
df["NOMBRE/RAZÓN SOCIAL"].value_counts()
# Out:
# NOMBRE/RAZÓN SOCIAL
# Transmisora Colombiana de Energía S.A.S E.S.P    403
# UNVERSIDAD DEL TOLIMA                            301
# CESAR AUGUSTO DUQUE CASTRILLON                   185
# E-LECTRICA S.A.S                                  89
# Proicom S.A.S                                     61
#                                                 ...
# Ana Maria Millan                                   1
# Juan Alberto Escobar                               1
# Silvia Restrepo Restrepo                           1
# Juan Felipe Girlado                                1
# Universidad Industrial de Santander                1
# Name: count, Length: 137, dtype: int64

# %%
df["TIPO DE CAZA"].value_counts()
# Out:
# TIPO DE CAZA
# Científica estudios ambientales    1370
# Científica no comercial              90
# Comercial                            65
# Fomento                               1
# Name: count, dtype: int64

# %%
df["ESPECIE O GRUPO TAXONÓMICO"].value_counts()
# Out:
# ESPECIE O GRUPO TAXONÓMICO
# Vertebrado                 327
# Invertebrado                20
# Amazona ochrocephala        18
# Brotogeris jugularis        14
# Sicalis flaveola            10
#                           ...
# Sachatamia punctulata        1
# Pristimantis sp1             1
# Anolis cf. tolimensis        1
# Craugastor metriosistus      1
# Riama sp.                    1
# Name: count, Length: 809, dtype: int64

# %%
df["No. INDIVIDUOS y/o MUESTRAS APROBADOS"].value_counts()
# Out:
# No. INDIVIDUOS y/o MUESTRAS APROBADOS
# No registra                                                            433
# 1                                                                      159
# no se permitio colecta definitiva                                       95
# 2                                                                       91
# 10                                                                      47
# 3                                                                       47
# 4                                                                       40
# No especifico                                                           31
# 5                                                                       24
# máx. 2 para captura definitiva                                          21
# 7                                                                       20
# 6                                                                       18
# ...

# %%
df["DEPARTAMENTO"].value_counts()
# Out:
# DEPARTAMENTO
# Tolima             603
# Risaralda          495
# Caldas             347
# Valle del Cauca     16
# Quindío             14
# Boyacá              12
# Cauca               10
# No registra          9
# La Guajira           7
# Cundinamarca         4
# Magdalena            3
# Chocó                2
# Santander            1
# Bolívar              1
# Casanare             1
# Huila                1
# Name: count, dtype: int64

# %%
df["ESTADO DE CONSERVACIÓN DE LA ESPECIE"].value_counts()
# Out:
# ESTADO DE CONSERVACIÓN DE LA ESPECIE
# Preocupación menor (LC)                                  878
# Datos insuficientes (DD) o especies No evaluadas (NE)    179
# No registra                                               55
# Vulnerable (VU)                                           12
# En Peligro (EN) o En Peligro Crítico (CR)                  7
# Casi amenazada (NT)                                        6
# E                                                          6
# Name: count, dtype: int64

# %%
df["No. ESPECÍMENES O MUESTRAS (Es)"].value_counts()
# Out:
# No. ESPECÍMENES O MUESTRAS (Es)
# 1      576
# 2      265
# 3      113
# 4       94
# 5       79
#       ...
# 533      1
# 56       1
# 63       1
# 54       1
# 28       1
# Name: count, Length: 76, dtype: int64

# %%
df["TARIFA MÍNIMA (TM)"].value_counts()
# Out:
# TARIFA MÍNIMA (TM)
# $    11,318.00    535
# $    10,903.00    348
# $    11,748.00    184
# $    10,152.00    170
# $    10,567.00    152
# $    9,600.00      87
# $    - 0           50
# Name: count, dtype: int64

# %%
df["MONTO A PAGAR (MP)"].value_counts()
# Out:
# MONTO A PAGAR (MP)
# $    - 0           385
# $    5,432.64       90
# $    5,233.00       72
# $    5,639.00       72
# $    10,865.28      65
#                   ...
# $    348,483.09      1
# $    312,660.96      1
# $    88,534.89       1
# $    216,289.92      1
# $    31,557.00       1
# Name: count, Length: 203, dtype: int64

# %%
df["RECAUDO"].value_counts()
# Out:
# RECAUDO
# $    - 0           559
# $    5,432.64       90
# $    5,233.00       72
# $    10,865.28      65
# $    981.00         57
#                   ...
# $    118,420.00      1
# $    108,653.00      1
# $    104,669.00      1
# $    97,788.00       1
# $    31,557.00       1
# Name: count, Length: 149, dtype: int64

# %%
df["RECLAMACIONES"].value_counts()
# Out:
# RECLAMACIONES
# No             1072
# No registra     452
# Si                2
# Name: count, dtype: int64

# %%
df["MUNICIPIO"].value_counts()
# Out:
# MUNICIPIO
# La Virginia                                                                                                                                                                        403
# Dolores, Natagaima, Prado, Purificación, Cunday,Cunday, Venadillo, Alvarado, Piedras, Ortega, Espinal, Guamo, Armero Guayabal, Mariquita, Roncesvalles, Coello, San Luis, Prado    301
# MANIZALES                                                                                                                                                                          114
# Santuario                                                                                                                                                                           89
# Coello                                                                                                                                                                              80
# ...

# %% [markdown]
# ## Tidy Location

# %%
df_location = df[["DEPARTAMENTO","MUNICIPIO"]]
df_location
# Out:
#       DEPARTAMENTO                                          MUNICIPIO
# 0           Tolima  Dolores, Natagaima, Prado, Purificación, Cunda...
# 1           Tolima  Dolores, Natagaima, Prado, Purificación, Cunda...
# 2           Tolima  Dolores, Natagaima, Prado, Purificación, Cunda...
# 3           Tolima  Dolores, Natagaima, Prado, Purificación, Cunda...
# 4           Tolima  Dolores, Natagaima, Prado, Purificación, Cunda...
# ...            ...                                                ...
# 1521        Tolima                                        No registra
# 1522        Tolima                                        No registra
# 1523        Tolima                                        No registra
# 1524  Cundinamarca                                        Bogotá D.C.
# 1525  Cundinamarca                                        Bogotá D.C.
#
# [1526 rows x 2 columns]

# %%
df1 = df_location.drop_duplicates()["DEPARTAMENTO"]
df1
# Out:
# 0             Tolima
# 107           Tolima
# 114           Tolima
# 193           Tolima
# 340           Tolima
#             ...
# 983            Huila
# 985       La Guajira
# 990        Risaralda
# 1393       Risaralda
# 1524    Cundinamarca
# Name: DEPARTAMENTO, Length: 66, dtype: object

# %%
df2 = df_location.drop_duplicates()["MUNICIPIO"]
# .str.split(', ')
df2
# df3 = df2.explode("MUNICIPIO", ignore_index=True)
# Out:
# 0       Dolores, Natagaima, Prado, Purificación, Cunda...
# 107                                       Armero-Guayabal
# 114                                                Rovira
# 193                                                Coello
# 340     Ambalema, Armero Guayabal, Casabianca, Fálan, ...
#                               ...
# 983                                               Acevedo
# 985                           1. Riohacha\n2. Sitio Nuevo
# 990                                           La Virginia
# 1393                                            Santuario
# 1524                                          Bogotá D.C.
# Name: MUNICIPIO, Length: 66, dtype: object

# %%
df3 = df2.str.split(', ')
df4 = df3.explode()
df4
# Out:
# 0                           Dolores
# 0                         Natagaima
# 0                             Prado
# 0                      Purificación
# 0                     Cunday,Cunday
#                    ...
# 983                         Acevedo
# 985     1. Riohacha\n2. Sitio Nuevo
# 990                     La Virginia
# 1393                      Santuario
# 1524                    Bogotá D.C.
# Name: MUNICIPIO, Length: 111, dtype: object

# %%
merged_df = df4.merge(df1, left_index=True, right_index=True, how='left')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/f7/k6yyvq9j73ddchn64ylh4m2r0000gn/T/ipykernel_99594/1995061420.py in ?()
# ----> 1 merged_df = df4.merge(df1, left_index=True, right_index=True, how='left')
#
# ~/.pyenv/versions/3.10.11/lib/python3.10/site-packages/pandas/core/generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'merge'

# %%
df_merged = pd.concat([df1, df4], axis=1)
df_merged
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[260], line 1
# ----> 1 df_merged = pd.concat([df1, df4], axis=1)
#       2 df_merged
#
# File ~/.pyenv/versions/3.10.11/lib/python3.10/site-packages/pandas/core/reshape/concat.py:385, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     370     copy = False
#     372 op = _Concatenator(
#     373     objs,
#     374     axis=axis,
#    (...)
#     382     sort=sort,
#     383 )
# --> 385 return op.get_result()
#
# File ~/.pyenv/versions/3.10.11/lib/python3.10/site-packages/pandas/core/reshape/concat.py:592, in _Concatenator.get_result(self)
#     589 cons = sample._constructor_expanddim
#     591 index, columns = self.new_axes
# --> 592 df = cons(data, index=index, copy=self.copy)
#     593 df.columns = columns
#     594 return df.__finalize__(self, method="concat")
#
# ...

# %%
df_copy = df.copy()
df_copy["ESPECIE O GRUPO TAXONÓMICO"]
# Out:
# 0                                       Panthiades bitias
# 1                                         Actinote anteas
# 2                                        Altinote dicaeus
# 3                              Catasticta tomyris tomyris
# 4                                           Colias dimera
#                               ...
# 1521           Amazona ochropcephala-Brotogeris jugularis
# 1522                                            Amazon sp
# 1523                                 Amazona ochrocephala
# 1524    Exitianus atratus, Dalbulus sp., Haldorus sp.,...
# 1525                                            Riama sp.
# Name: ESPECIE O GRUPO TAXONÓMICO, Length: 1526, dtype: object

# %% [markdown]
# ## Tidy Species

# %%
species = df_copy.copy()
species
# Out:
#        Año Autoridad Ambiental                  NOMBRE/RAZÓN SOCIAL  \
# 0     2021           CORTOLIMA                UNVERSIDAD DEL TOLIMA
# 1     2021           CORTOLIMA                UNVERSIDAD DEL TOLIMA
# 2     2021           CORTOLIMA                UNVERSIDAD DEL TOLIMA
# 3     2021           CORTOLIMA                UNVERSIDAD DEL TOLIMA
# 4     2021           CORTOLIMA                UNVERSIDAD DEL TOLIMA
# ...    ...                 ...                                  ...
# 1521  2020           CORTOLIMA                   Martha Ortiz Prada
# 1522  2020           CORTOLIMA       Fernando Aurelio Acevedo Marin
# 1523  2020           CORTOLIMA          Aura Maria Serrano Cuadrado
# 1524  2021                 SDA    Universidad Militar Nueva Granada
# 1525  2022                 SDA  Universidad Industrial de Santander
#
#      PERSONA NATURAL O JURÍDICA   REPRESENTANTE LEGAL  \
# 0              Persona jurídica  Omar A. Mejía Patiño
# ...

# %%
species["ESPECIE O GRUPO TAXONÓMICO"]
# Out:
# 0                                       Panthiades bitias
# 1                                         Actinote anteas
# 2                                        Altinote dicaeus
# 3                              Catasticta tomyris tomyris
# 4                                           Colias dimera
#                               ...
# 1521           Amazona ochropcephala-Brotogeris jugularis
# 1522                                            Amazon sp
# 1523                                 Amazona ochrocephala
# 1524    Exitianus atratus, Dalbulus sp., Haldorus sp.,...
# 1525                                            Riama sp.
# Name: ESPECIE O GRUPO TAXONÓMICO, Length: 1526, dtype: object

# %%
species["ESPECIE O GRUPO TAXONÓMICO"] = species["ESPECIE O GRUPO TAXONÓMICO"].str.strip()
(species["ESPECIE O GRUPO TAXONÓMICO"])
# species1 = species.explode("ESPECIE O GRUPO TAXONÓMICO", ignore_index=True)
# species1
# Out:
# 0                                       Panthiades bitias
# 1                                         Actinote anteas
# 2                                        Altinote dicaeus
# 3                              Catasticta tomyris tomyris
# 4                                           Colias dimera
#                               ...
# 1521           Amazona ochropcephala-Brotogeris jugularis
# 1522                                            Amazon sp
# 1523                                 Amazona ochrocephala
# 1524    Exitianus atratus, Dalbulus sp., Haldorus sp.,...
# 1525                                            Riama sp.
# Name: ESPECIE O GRUPO TAXONÓMICO, Length: 1526, dtype: object

# %%
import re

# %%
p_parentheses = r'\([^()]*\)'

# %%
species["ESPECIE O GRUPO TAXONÓMICO"] = species["ESPECIE O GRUPO TAXONÓMICO"].str.replace(p_parentheses,'',regex=True)
(species["ESPECIE O GRUPO TAXONÓMICO"])
# species1 = species.explode("ESPECIE O GRUPO TAXONÓMICO", ignore_index=True)
# species1
# Out:
# 0                                       Panthiades bitias
# 1                                         Actinote anteas
# 2                                        Altinote dicaeus
# 3                              Catasticta tomyris tomyris
# 4                                           Colias dimera
#                               ...
# 1521           Amazona ochropcephala-Brotogeris jugularis
# 1522                                            Amazon sp
# 1523                                 Amazona ochrocephala
# 1524    Exitianus atratus, Dalbulus sp., Haldorus sp.,...
# 1525                                            Riama sp.
# Name: ESPECIE O GRUPO TAXONÓMICO, Length: 1526, dtype: object

# %%
species["ESPECIE O GRUPO TAXONÓMICO"] = species["ESPECIE O GRUPO TAXONÓMICO"].str.replace("Psocoptera Fam:",'',regex=True)
(species["ESPECIE O GRUPO TAXONÓMICO"])
# Out:
# 0                                       Panthiades bitias
# 1                                         Actinote anteas
# 2                                        Altinote dicaeus
# 3                              Catasticta tomyris tomyris
# 4                                           Colias dimera
#                               ...
# 1521           Amazona ochropcephala-Brotogeris jugularis
# 1522                                            Amazon sp
# 1523                                 Amazona ochrocephala
# 1524    Exitianus atratus, Dalbulus sp., Haldorus sp.,...
# 1525                                            Riama sp.
# Name: ESPECIE O GRUPO TAXONÓMICO, Length: 1526, dtype: object

# %%
species["ESPECIE O GRUPO TAXONÓMICO"] = species["ESPECIE O GRUPO TAXONÓMICO"].str.replace("Psocidia-Psocoptera Fam:",'',regex=True)
(species["ESPECIE O GRUPO TAXONÓMICO"])
# Out:
# 0                                       Panthiades bitias
# 1                                         Actinote anteas
# 2                                        Altinote dicaeus
# 3                              Catasticta tomyris tomyris
# 4                                           Colias dimera
#                               ...
# 1521           Amazona ochropcephala-Brotogeris jugularis
# 1522                                            Amazon sp
# 1523                                 Amazona ochrocephala
# 1524    Exitianus atratus, Dalbulus sp., Haldorus sp.,...
# 1525                                            Riama sp.
# Name: ESPECIE O GRUPO TAXONÓMICO, Length: 1526, dtype: object

# %%
species["ESPECIE O GRUPO TAXONÓMICO"] = species["ESPECIE O GRUPO TAXONÓMICO"].str.strip()
(species["ESPECIE O GRUPO TAXONÓMICO"])
# species1 = species.explode("ESPECIE O GRUPO TAXONÓMICO", ignore_index=True)
# species1
# Out:
# 0                                       Panthiades bitias
# 1                                         Actinote anteas
# 2                                        Altinote dicaeus
# 3                              Catasticta tomyris tomyris
# 4                                           Colias dimera
#                               ...
# 1521           Amazona ochropcephala-Brotogeris jugularis
# 1522                                            Amazon sp
# 1523                                 Amazona ochrocephala
# 1524    Exitianus atratus, Dalbulus sp., Haldorus sp.,...
# 1525                                            Riama sp.
# Name: ESPECIE O GRUPO TAXONÓMICO, Length: 1526, dtype: object

# %%
species["ESPECIE O GRUPO TAXONÓMICO"] = species["ESPECIE O GRUPO TAXONÓMICO"].str.split("\n")
# (species["ESPECIE O GRUPO TAXONÓMICO"])
species1 = species.explode("ESPECIE O GRUPO TAXONÓMICO", ignore_index=True)
species1
# Out:
#        Año Autoridad Ambiental                  NOMBRE/RAZÓN SOCIAL  \
# 0     2021           CORTOLIMA                UNVERSIDAD DEL TOLIMA
# 1     2021           CORTOLIMA                UNVERSIDAD DEL TOLIMA
# 2     2021           CORTOLIMA                UNVERSIDAD DEL TOLIMA
# 3     2021           CORTOLIMA                UNVERSIDAD DEL TOLIMA
# 4     2021           CORTOLIMA                UNVERSIDAD DEL TOLIMA
# ...    ...                 ...                                  ...
# 1566  2020           CORTOLIMA                   Martha Ortiz Prada
# 1567  2020           CORTOLIMA       Fernando Aurelio Acevedo Marin
# 1568  2020           CORTOLIMA          Aura Maria Serrano Cuadrado
# 1569  2021                 SDA    Universidad Militar Nueva Granada
# 1570  2022                 SDA  Universidad Industrial de Santander
#
#      PERSONA NATURAL O JURÍDICA   REPRESENTANTE LEGAL  \
# 0              Persona jurídica  Omar A. Mejía Patiño
# ...

# %%
species1["ESPECIE O GRUPO TAXONÓMICO"]
# Out:
# 0                                       Panthiades bitias
# 1                                         Actinote anteas
# 2                                        Altinote dicaeus
# 3                              Catasticta tomyris tomyris
# 4                                           Colias dimera
#                               ...
# 1566           Amazona ochropcephala-Brotogeris jugularis
# 1567                                            Amazon sp
# 1568                                 Amazona ochrocephala
# 1569    Exitianus atratus, Dalbulus sp., Haldorus sp.,...
# 1570                                            Riama sp.
# Name: ESPECIE O GRUPO TAXONÓMICO, Length: 1571, dtype: object

# %%
species1["ESPECIE O GRUPO TAXONÓMICO"] = species1["ESPECIE O GRUPO TAXONÓMICO"].str.split('-')
# (species["ESPECIE O GRUPO TAXONÓMICO"])
species2 = species1.explode("ESPECIE O GRUPO TAXONÓMICO", ignore_index=True)
species2
# Out:
#        Año Autoridad Ambiental                  NOMBRE/RAZÓN SOCIAL  \
# 0     2021           CORTOLIMA                UNVERSIDAD DEL TOLIMA
# 1     2021           CORTOLIMA                UNVERSIDAD DEL TOLIMA
# 2     2021           CORTOLIMA                UNVERSIDAD DEL TOLIMA
# 3     2021           CORTOLIMA                UNVERSIDAD DEL TOLIMA
# 4     2021           CORTOLIMA                UNVERSIDAD DEL TOLIMA
# ...    ...                 ...                                  ...
# 1582  2020           CORTOLIMA                   Martha Ortiz Prada
# 1583  2020           CORTOLIMA       Fernando Aurelio Acevedo Marin
# 1584  2020           CORTOLIMA          Aura Maria Serrano Cuadrado
# 1585  2021                 SDA    Universidad Militar Nueva Granada
# 1586  2022                 SDA  Universidad Industrial de Santander
#
#      PERSONA NATURAL O JURÍDICA   REPRESENTANTE LEGAL  \
# 0              Persona jurídica  Omar A. Mejía Patiño
# ...

# %%
species2["ESPECIE O GRUPO TAXONÓMICO"]
# Out:
# 0                                       Panthiades bitias
# 1                                         Actinote anteas
# 2                                        Altinote dicaeus
# 3                              Catasticta tomyris tomyris
# 4                                           Colias dimera
#                               ...
# 1582                                 Brotogeris jugularis
# 1583                                            Amazon sp
# 1584                                 Amazona ochrocephala
# 1585    Exitianus atratus, Dalbulus sp., Haldorus sp.,...
# 1586                                            Riama sp.
# Name: ESPECIE O GRUPO TAXONÓMICO, Length: 1587, dtype: object

# %%
species2["ESPECIE O GRUPO TAXONÓMICO"] = species2["ESPECIE O GRUPO TAXONÓMICO"].str.split(', ')
# (species["ESPECIE O GRUPO TAXONÓMICO"])
species3 = species2.explode("ESPECIE O GRUPO TAXONÓMICO", ignore_index=True)
# species3
species3["ESPECIE O GRUPO TAXONÓMICO"]
# Out:
# 0                Panthiades bitias
# 1                  Actinote anteas
# 2                 Altinote dicaeus
# 3       Catasticta tomyris tomyris
# 4                    Colias dimera
#                    ...
# 1640             Exitianus atratus
# 1641                  Dalbulus sp.
# 1642                  Haldorus sp.
# 1643              Cicadellidae sp.
# 1644                     Riama sp.
# Name: ESPECIE O GRUPO TAXONÓMICO, Length: 1645, dtype: object

# %%
species3["ESPECIE O GRUPO TAXONÓMICO"] = species3["ESPECIE O GRUPO TAXONÓMICO"].str.split('y ')
# (species["ESPECIE O GRUPO TAXONÓMICO"])
species4 = species3.explode("ESPECIE O GRUPO TAXONÓMICO", ignore_index=True)
# species4
species4["ESPECIE O GRUPO TAXONÓMICO"]
# Out:
# 0                Panthiades bitias
# 1                  Actinote anteas
# 2                 Altinote dicaeus
# 3       Catasticta tomyris tomyris
# 4                    Colias dimera
#                    ...
# 1652             Exitianus atratus
# 1653                  Dalbulus sp.
# 1654                  Haldorus sp.
# 1655              Cicadellidae sp.
# 1656                     Riama sp.
# Name: ESPECIE O GRUPO TAXONÓMICO, Length: 1657, dtype: object

# %% [markdown]
# ## =============== ESPECIES SOLICITADAS ===============

# %%
species4.to_csv('species4.csv')

# %% [markdown]
# ### ==============================

# %% [markdown]
# Con species4 puedo
# - contar cuántas muestras piden de cada especies.
# - ver cuáles especies permiten más
# - ver cuáles especies niegan más
# - ver cuáles especies recaudan más
# - ver si el recaudo de las especies es suficiente.

# %%
species4["ESPECIE O GRUPO TAXONÓMICO"].value_counts()
# Out:
# ESPECIE O GRUPO TAXONÓMICO
# Vertebrado                    327
# Invertebrado                   20
# Amazona ochrocephala           18
# Brotogeris jugularis           15
# Sicalis flaveola               10
#                              ...
# Micronycteris                   1
# Andinobates dorisswansonae      1
# Bentos                          1
# Creagrutus affinis              1
# Riama sp.                       1
# Name: count, Length: 906, dtype: int64

# %%
species4["ESPECIE O GRUPO TAXONÓMICO"] = species4["ESPECIE O GRUPO TAXONÓMICO"].str.strip()
species4.head()
# Out:
#     Año Autoridad Ambiental    NOMBRE/RAZÓN SOCIAL PERSONA NATURAL O JURÍDICA  \
# 0  2021           CORTOLIMA  UNVERSIDAD DEL TOLIMA           Persona jurídica
# 1  2021           CORTOLIMA  UNVERSIDAD DEL TOLIMA           Persona jurídica
# 2  2021           CORTOLIMA  UNVERSIDAD DEL TOLIMA           Persona jurídica
# 3  2021           CORTOLIMA  UNVERSIDAD DEL TOLIMA           Persona jurídica
# 4  2021           CORTOLIMA  UNVERSIDAD DEL TOLIMA           Persona jurídica
#
#     REPRESENTANTE LEGAL       TIPO DE AUTORIZACIÓN / ENTIDAD QUE OTORGA  \
# 0  Omar A. Mejía Patiño  Permiso / Autoridad Ambiental diferente a ANLA
# 1  Omar A. Mejía Patiño  Permiso / Autoridad Ambiental diferente a ANLA
# 2  Omar A. Mejía Patiño  Permiso / Autoridad Ambiental diferente a ANLA
# 3  Omar A. Mejía Patiño  Permiso / Autoridad Ambiental diferente a ANLA
# 4  Omar A. Mejía Patiño  Permiso / Autoridad Ambiental diferente a ANLA
#
# ...

# %%
species4["ESPECIE O GRUPO TAXONÓMICO"] = species4["ESPECIE O GRUPO TAXONÓMICO"].str.lower()
species4["ESPECIE O GRUPO TAXONÓMICO"].head()
# Out:
# 0             panthiades bitias
# 1               actinote anteas
# 2              altinote dicaeus
# 3    catasticta tomyris tomyris
# 4                 colias dimera
# Name: ESPECIE O GRUPO TAXONÓMICO, dtype: object

# %%
species4["ESPECIE O GRUPO TAXONÓMICO"] = species4["ESPECIE O GRUPO TAXONÓMICO"].str.replace("  ",' ',regex=True)
species4["ESPECIE O GRUPO TAXONÓMICO"] = species4["ESPECIE O GRUPO TAXONÓMICO"].str.replace("vertebrados",'vertebrado',regex=True)
species4["ESPECIE O GRUPO TAXONÓMICO"] = species4["ESPECIE O GRUPO TAXONÓMICO"].str.replace("invertebrados",'invertebrado',regex=True)

# %% [markdown]
# ## Species requested

# %%
species4["ESPECIE O GRUPO TAXONÓMICO"].value_counts()
# Out:
# ESPECIE O GRUPO TAXONÓMICO
# vertebrado                    343
# invertebrado                   31
# amazona ochrocephala           18
# brotogeris jugularis           15
# sicalis flaveola               10
#                              ...
# myiozetetes similis             1
# xenopipo atronitens             1
# micronycteris                   1
# andinobates dorisswansonae      1
# riama sp.                       1
# Name: count, Length: 874, dtype: int64

# %%
species_count = species4["ESPECIE O GRUPO TAXONÓMICO"].value_counts()
species_count_df = pd.DataFrame(species_count).reset_index()
species_count_df.columns = ['species','requests']
species_count_df.to_csv('species_requests.csv',index=False)

# %% [markdown]
# ## Species individuals

# %%
individuals_requested = species4.groupby("ESPECIE O GRUPO TAXONÓMICO")["No. INDIVIDUOS y/o MUESTRAS APROBADOS"].sum().reset_index()
individuals_requested
# Out:
#                         ESPECIE O GRUPO TAXONÓMICO  \
# 0      04 especímenes por morfoespecie de insectos
# 1                          15 cascaras por especie
# 2    40 especímenes por especie por área protegida
# 3                               accipiter striatus
# 4                                  actinote anteas
# ..                                             ...
# 869                             zenaida auriculata
# 870                             zimmerius chrysops
# 871                           zonotrichia capensis
# 872                                     zooplacton
# 873                                    zooplancton
#
#      No. INDIVIDUOS y/o MUESTRAS APROBADOS
# 0                            No especifico
# 1                            No especifico
# 2                            No especifico
# 3                                        2
# 4                              No registra
# ..                                     ...
# ...

# %%
def print_integer_or_zero(str_number):
    try:
        int_number = int(str_number)
        print(int_number)
    except ValueError:
        print(0)

# %%
sum = 0
for row in species4["No. INDIVIDUOS y/o MUESTRAS APROBADOS"]:
    # if int(row) != ValueError:
    #     sum += int(row)
    # else:
    #     sum += 0
    try:
        individual = int(row)
        sum += individual
    except ValueError:
        sum += 0
    # print(individual)
#     sum += individual
sum
# Out:
# 7377

# %%
sum = 0
for row in species4["No. ESPECÍMENES O MUESTRAS (Es)"]:

    try:
        individual = int(row)
        sum += individual
    except ValueError:
        sum += 0

sum
# Out:
# 24074

# %%
species5 = species4.copy()

# %%
for row in species5["No. INDIVIDUOS y/o MUESTRAS APROBADOS"]:
    # if int(row) != ValueError:
    #     sum += int(row)
    # else:
    #     sum += 0
    try:
        individual = int(row)
        row == individual
    except ValueError:
        row == 0
    # print(individual)
#     sum += individual
species5["No. INDIVIDUOS y/o MUESTRAS APROBADOS"]
# Out:
# 0       No registra
# 1       No registra
# 2       No registra
# 3       No registra
# 4       No registra
#            ...
# 1652     No reporta
# 1653     No reporta
# 1654     No reporta
# 1655     No reporta
# 1656     No reporta
# Name: No. INDIVIDUOS y/o MUESTRAS APROBADOS, Length: 1657, dtype: object

# %%
species5["No. INDIVIDUOS y/o MUESTRAS APROBADOS"] = pd.to_numeric(species5["No. INDIVIDUOS y/o MUESTRAS APROBADOS"],errors='coerce').fillna(0).astype(int)
species5["No. INDIVIDUOS y/o MUESTRAS APROBADOS"]
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1652    0
# 1653    0
# 1654    0
# 1655    0
# 1656    0
# Name: No. INDIVIDUOS y/o MUESTRAS APROBADOS, Length: 1657, dtype: int64

# %%
individuals_approved = species5.groupby("ESPECIE O GRUPO TAXONÓMICO")["No. INDIVIDUOS y/o MUESTRAS APROBADOS"].sum().reset_index()
individuals_approved.sort_values(by="No. INDIVIDUOS y/o MUESTRAS APROBADOS",ascending=False).head(7)
# Out:
#     ESPECIE O GRUPO TAXONÓMICO  No. INDIVIDUOS y/o MUESTRAS APROBADOS
# 402               invertebrado                                   4552
# 857                 vertebrado                                    207
# 249      dendrobates truncatus                                     92
# 155     carollia perspicillata                                     91
# 433    lithobates catesbeianus                                     85
# 348      gonatodes albogularis                                     53
# 647     pristimantis permixtus                                     44

# %%
species5["No. ESPECÍMENES O MUESTRAS (Es)"] = pd.to_numeric(species5["No. ESPECÍMENES O MUESTRAS (Es)"],errors='coerce').fillna(0).astype(int)
species5["No. ESPECÍMENES O MUESTRAS (Es)"]
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1652    4
# 1653    4
# 1654    4
# 1655    4
# 1656    1
# Name: No. ESPECÍMENES O MUESTRAS (Es), Length: 1657, dtype: int64

# %%
individuals_hunted = species5.groupby("ESPECIE O GRUPO TAXONÓMICO")["No. ESPECÍMENES O MUESTRAS (Es)"].sum().reset_index()
individuals_hunted.sort_values(by="No. ESPECÍMENES O MUESTRAS (Es)",ascending=False).head(7)
# Out:
#          ESPECIE O GRUPO TAXONÓMICO  No. ESPECÍMENES O MUESTRAS (Es)
# 402                    invertebrado                            13586
# 857                      vertebrado                             2908
# 141              calosoma alternans                              302
# 718                 serinus canaria                              218
# 669                        psocidia                              198
# 670  psocoptera fam : ptiloneuridae                              198
# 297                     epipsocidae                              198

# %% [markdown]
# ## Specimens

# %%
specimens = df_copy.copy()

# %%
specimens["ESPECIE O GRUPO TAXONÓMICO"] = specimens["ESPECIE O GRUPO TAXONÓMICO"].str.lower()

specimens["ESPECIE O GRUPO TAXONÓMICO"] = specimens["ESPECIE O GRUPO TAXONÓMICO"].str.strip()

# %%
specimens["ESPECIE O GRUPO TAXONÓMICO"] = specimens["ESPECIE O GRUPO TAXONÓMICO"].str.replace(p_parentheses,'',regex=True)

# %%
specimens["ESPECIE O GRUPO TAXONÓMICO"] = specimens["ESPECIE O GRUPO TAXONÓMICO"].str.replace("  ",' ',regex=True)

# %%
specimens["ESPECIE O GRUPO TAXONÓMICO"] = specimens["ESPECIE O GRUPO TAXONÓMICO"].str.replace("psocoptera fam:",'',regex=True)

# %%
specimens["ESPECIE O GRUPO TAXONÓMICO"] = specimens["ESPECIE O GRUPO TAXONÓMICO"].str.replace("psocoptera fam :",'',regex=True)

# %%
specimens["ESPECIE O GRUPO TAXONÓMICO"] = specimens["ESPECIE O GRUPO TAXONÓMICO"].str.replace("psocidia-psocoptera fam:",'',regex=True)

# %%
specimens["ESPECIE O GRUPO TAXONÓMICO"] = specimens["ESPECIE O GRUPO TAXONÓMICO"].str.replace("vertebrados",'vertebrado',regex=True)
specimens["ESPECIE O GRUPO TAXONÓMICO"] = specimens["ESPECIE O GRUPO TAXONÓMICO"].str.replace("invertebrados",'invertebrado',regex=True)

# %%
(specimens["ESPECIE O GRUPO TAXONÓMICO"])
# Out:
# 0                                       panthiades bitias
# 1                                         actinote anteas
# 2                                        altinote dicaeus
# 3                              catasticta tomyris tomyris
# 4                                           colias dimera
#                               ...
# 1521           amazona ochropcephala-brotogeris jugularis
# 1522                                            amazon sp
# 1523                                 amazona ochrocephala
# 1524    exitianus atratus, dalbulus sp., haldorus sp.,...
# 1525                                            riama sp.
# Name: ESPECIE O GRUPO TAXONÓMICO, Length: 1526, dtype: object

# %%
specimens["No. INDIVIDUOS y/o MUESTRAS APROBADOS"] = pd.to_numeric(specimens["No. INDIVIDUOS y/o MUESTRAS APROBADOS"],errors='coerce').fillna(0).astype(int)
specimens["No. INDIVIDUOS y/o MUESTRAS APROBADOS"]
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1521    0
# 1522    1
# 1523    2
# 1524    0
# 1525    0
# Name: No. INDIVIDUOS y/o MUESTRAS APROBADOS, Length: 1526, dtype: int64

# %%
specimens["No. ESPECÍMENES O MUESTRAS (Es)"] = pd.to_numeric(specimens["No. ESPECÍMENES O MUESTRAS (Es)"],errors='coerce').fillna(0).astype(int)
specimens["No. ESPECÍMENES O MUESTRAS (Es)"]
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1521    2
# 1522    1
# 1523    2
# 1524    4
# 1525    1
# Name: No. ESPECÍMENES O MUESTRAS (Es), Length: 1526, dtype: int64

# %% [markdown]
# ## =============== ESPECÍMINES APROBADOS ===============

# %%
specimens_approved = specimens.groupby("ESPECIE O GRUPO TAXONÓMICO")["No. INDIVIDUOS y/o MUESTRAS APROBADOS"].sum().reset_index()
specimens_approved.sort_values(by="No. INDIVIDUOS y/o MUESTRAS APROBADOS",ascending=False).head(7)
# Out:
#     ESPECIE O GRUPO TAXONÓMICO  No. INDIVIDUOS y/o MUESTRAS APROBADOS
# 357               invertebrado                                   4552
# 776                 vertebrado                                    207
# 224      dendrobates truncatus                                     92
# 140     carollia perspicillata                                     91
# 385    lithobates catesbeianus                                     85
# 312      gonatodes albogularis                                     53
# 595    pristimantis uranobates                                     44

# %% [markdown]
# ## =============== ESPECÍMENES RECOLECTADOS ===============

# %%
specimens_hunted = specimens.groupby("ESPECIE O GRUPO TAXONÓMICO")["No. ESPECÍMENES O MUESTRAS (Es)"].sum().reset_index()
specimens_hunted.sort_values(by="No. ESPECÍMENES O MUESTRAS (Es)",ascending=False).head(7)
# Out:
#                             ESPECIE O GRUPO TAXONÓMICO  \
# 357                                       invertebrado
# 776                                         vertebrado
# 127                                 calosoma alternans
# 647                                    serinus canaria
# 0     psocidia- lachesillidae\n ptiloneuridae\nepip...
# 140                             carollia perspicillata
# 224                              dendrobates truncatus
#
#      No. ESPECÍMENES O MUESTRAS (Es)
# 357                            13586
# 776                             2908
# 127                              302
# 647                              218
# 0                                198
# 140                              130
# 224                              122

# %% [markdown]
# ### ==============================

# %%
specimens_count = specimens["ESPECIE O GRUPO TAXONÓMICO"].value_counts()
specimens_count_df = pd.DataFrame(specimens_count).reset_index()
specimens_count_df.columns = ['species','requests']
specimens_count_df.to_csv('specimes_requests.csv',index=False)

# %% [markdown]
# ## Money

# %%
money = df_copy.copy()

# %%
money
# Out:
#        Año Autoridad Ambiental                  NOMBRE/RAZÓN SOCIAL  \
# 0     2021           CORTOLIMA                UNVERSIDAD DEL TOLIMA
# 1     2021           CORTOLIMA                UNVERSIDAD DEL TOLIMA
# 2     2021           CORTOLIMA                UNVERSIDAD DEL TOLIMA
# 3     2021           CORTOLIMA                UNVERSIDAD DEL TOLIMA
# 4     2021           CORTOLIMA                UNVERSIDAD DEL TOLIMA
# ...    ...                 ...                                  ...
# 1521  2020           CORTOLIMA                   Martha Ortiz Prada
# 1522  2020           CORTOLIMA       Fernando Aurelio Acevedo Marin
# 1523  2020           CORTOLIMA          Aura Maria Serrano Cuadrado
# 1524  2021                 SDA    Universidad Militar Nueva Granada
# 1525  2022                 SDA  Universidad Industrial de Santander
#
#      PERSONA NATURAL O JURÍDICA   REPRESENTANTE LEGAL  \
# 0              Persona jurídica  Omar A. Mejía Patiño
# ...

# %%
test = money[money["RECAUDO"] == "Pendiente"]

test
# Out:
#       Año Autoridad Ambiental            NOMBRE/RAZÓN SOCIAL  \
# 918  2018        CORPOGUAJIRA                 ECOPLANET LTDA
# 920  2018        CORPOGUAJIRA  Carbones del Cerrejón Limited
# 921  2018        CORPOGUAJIRA       Renovatio Group Limited.
# 922  2018        CORPOGUAJIRA       Renovatio Group Limited.
#
#     PERSONA NATURAL O JURÍDICA          REPRESENTANTE LEGAL  \
# 918           Persona jurídica             Luz Elena Suárez
# 920           Persona jurídica        Jaime Brito Lallemand
# 921           Persona jurídica  Juan Pablo Orozco Velasquez
# 922           Persona jurídica  Juan Pablo Orozco Velasquez
#
#           TIPO DE AUTORIZACIÓN / ENTIDAD QUE OTORGA  \
# 918                                  Permiso / ANLA
# 920  Permiso / Autoridad Ambiental diferente a ANLA
# 921  Permiso / Autoridad Ambiental diferente a ANLA
# 922  Permiso / Autoridad Ambiental diferente a ANLA
#
#     No. PERMISO/ LICENCIA AMBIENTAL/ SANCIONATORIO    FECHA DE OTORGAMIENTO  \
# ...

# %%
money["RECAUDO"] = money["RECAUDO"].str.replace("$", "")
money["RECAUDO"] = money["RECAUDO"].str.replace("No registra", "0")
money["RECAUDO"] = money["RECAUDO"].str.replace(",", "")
money["RECAUDO"] = money["RECAUDO"].str.replace("Pendiente", "0")
money["RECAUDO"] = money["RECAUDO"].str.replace("    - 0", "0")
money["RECAUDO"] = money["RECAUDO"].str.replace(" ", "")

# %%
test = money[money["RECAUDO"] == "    - 0"]

test
# Out:
# Empty DataFrame
# Columns: [Año, Autoridad Ambiental, NOMBRE/RAZÓN SOCIAL, PERSONA NATURAL O JURÍDICA, REPRESENTANTE LEGAL, TIPO DE AUTORIZACIÓN / ENTIDAD QUE OTORGA, No. PERMISO/ LICENCIA AMBIENTAL/ SANCIONATORIO, FECHA DE OTORGAMIENTO, VIGENCIA (meses), TIPO DE CAZA, VALOR TIPO DE CAZA, ESPECIE O GRUPO TAXONÓMICO, ORDEN, CLASE, No. INDIVIDUOS y/o MUESTRAS APROBADOS, DEPARTAMENTO, MUNICIPIO, No. CERTIFICADO SiB, ESTADO DE CONSERVACIÓN DE LA ESPECIE, ESTADO DE CONSERVACIÓN DEL HÁBITAT, PRESIÓN POR USO, COEFICIENTE BIÓTICO (Cb), NACIONALIDAD (N), GRUPO TRÓFICO (Gt), COEFICIENTE DE VALORACIÓN
# (V), FACTOR REGIONAL (FR), No. ESPECÍMENES O MUESTRAS (Es), UNIDAD DE Es, TARIFA MÍNIMA (TM), COSTO DE IMPLEMENTACIÓN (CI), MONTO A PAGAR (MP), RECLAMACIONES, MP DESPUÉS DE RECLAMACIÓN, RECAUDO]
# Index: []
#
# [0 rows x 34 columns]

# %%
money["RECAUDO"] = money["RECAUDO"].astype(float)

# %%
money.dtypes
# Out:
# Año                                                 int64
# Autoridad Ambiental                                object
# NOMBRE/RAZÓN SOCIAL                                object
# PERSONA NATURAL O JURÍDICA                         object
# REPRESENTANTE LEGAL                                object
# TIPO DE AUTORIZACIÓN / ENTIDAD QUE OTORGA          object
# No. PERMISO/ LICENCIA AMBIENTAL/ SANCIONATORIO     object
# FECHA DE OTORGAMIENTO                              object
# VIGENCIA (meses)                                  float64
# TIPO DE CAZA                                       object
# VALOR TIPO DE CAZA                                float64
# ESPECIE O GRUPO TAXONÓMICO                         object
# ORDEN                                              object
# CLASE                                              object
# No. INDIVIDUOS y/o MUESTRAS APROBADOS              object
# DEPARTAMENTO                                       object
# ...

# %%
money.to_csv("money.csv", index=False)

# %% [markdown]
# ## =============== RECAUDO TOTAL ===============

# %%
money["RECAUDO"].sum()
# Out:
# 36434943.120000005

# %% [markdown]
# ### ===============================================

# %%
money["ESPECIE O GRUPO TAXONÓMICO"] = money["ESPECIE O GRUPO TAXONÓMICO"].str.lower()

money["ESPECIE O GRUPO TAXONÓMICO"] = money["ESPECIE O GRUPO TAXONÓMICO"].str.strip()

money["ESPECIE O GRUPO TAXONÓMICO"] = money["ESPECIE O GRUPO TAXONÓMICO"].str.replace(p_parentheses,'',regex=True)

money["ESPECIE O GRUPO TAXONÓMICO"] = money["ESPECIE O GRUPO TAXONÓMICO"].str.replace("  ",' ',regex=True)

money["ESPECIE O GRUPO TAXONÓMICO"] = money["ESPECIE O GRUPO TAXONÓMICO"].str.replace("psocoptera fam:",'',regex=True)

money["ESPECIE O GRUPO TAXONÓMICO"] = money["ESPECIE O GRUPO TAXONÓMICO"].str.replace("psocoptera fam :",'',regex=True)

money["ESPECIE O GRUPO TAXONÓMICO"] = money["ESPECIE O GRUPO TAXONÓMICO"].str.replace("psocidia-psocoptera fam:",'',regex=True)

money["ESPECIE O GRUPO TAXONÓMICO"] = money["ESPECIE O GRUPO TAXONÓMICO"].str.replace("vertebrados",'vertebrado',regex=True)
money["ESPECIE O GRUPO TAXONÓMICO"] = money["ESPECIE O GRUPO TAXONÓMICO"].str.replace("invertebrados",'invertebrado',regex=True)

# %% [markdown]
# ## =============== RECAUDO POR ESPECIE ===============

# %%
specimens_money = money.groupby("ESPECIE O GRUPO TAXONÓMICO")["RECAUDO"].sum().reset_index()
specimens_money.sort_values(by="RECAUDO",ascending=False).head(7)
# Out:
#     ESPECIE O GRUPO TAXONÓMICO     RECAUDO
# 580   pristimantis dorsopictus  2669055.00
# 224      dendrobates truncatus  1564509.20
# 647            serinus canaria  1184316.00
# 140     carollia perspicillata   780000.16
# 113       brotogeris jugularis   720755.64
# 584     pristimantis permixtus   597590.40
# 595    pristimantis uranobates   597590.40

# %% [markdown]
# ### ===============================================

# %%
conservation_money = money.groupby("ESTADO DE CONSERVACIÓN DE LA ESPECIE")["RECAUDO"].sum().reset_index()
conservation_money.sort_values(by="RECAUDO",ascending=False).head(7)
# Out:
#                 ESTADO DE CONSERVACIÓN DE LA ESPECIE  \
# 4                                        No registra
# 1  Datos insuficientes (DD) o especies No evaluad...
# 2                                                  E
# 0                                Casi amenazada (NT)
# 6                                    Vulnerable (VU)
# 3          En Peligro (EN) o En Peligro Crítico (CR)
# 5                            Preocupación menor (LC)
#
#                                              RECAUDO
# 4  Pendiente$    - 0PendientePendientePendiente$ ...
# 1  $    981.00$    981.00$    981.00$    981.00$ ...
# 2  $    488,937.60$    597,590.40$    27,163.20$ ...
# 0  $    39,251.00$    39,251.00$    - 0$    21,73...
# 6  $    26,167.00$    52,334.00$    104,669.00$  ...
# 3  $    11,278.00$    211,873.00$    - 0$    27,1...
# 5  $    1,963.00$    4,074.00$    5,233.00$    5,...
